# %%
import pandas as pd

# %%
file_path = '/home/fractaluser/Fractal/data/airline/unzipped'

# %%
df = pd.read_csv(file_path+'/1987.csv')

# %%
df['date'] = df['DayofMonth'].astype(str) + '-' + df['Month'].astype(str) + '-' + df['Year'].astype(str)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10          14          3    741.0         730    912.0
# 1  1987     10          15          4    729.0         730    903.0
# 2  1987     10          17          6    741.0         730    918.0
# 3  1987     10          18          7    729.0         730    847.0
# 4  1987     10          19          1    749.0         730    922.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ...  TaxiOut  Cancelled  \
# 0         849            PS       1451  ...      NaN          0
# 1         849            PS       1451  ...      NaN          0
# 2         849            PS       1451  ...      NaN          0
# 3         849            PS       1451  ...      NaN          0
# 4         849            PS       1451  ...      NaN          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0               NaN         0           NaN           NaN      NaN
# ...

# %%
for c in df.date.unique():
    (df[df.date == c]).to_csv(file_path+'/'+c+'.csv', index=False)
